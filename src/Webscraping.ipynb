# %% [markdown]
# this is the first step i will webscrpe this daily

# %%
import requests
import pandas as pd
import time
import  datetime
from time import sleep
import csv
from sqlalchemy import true

# %%
allPages = []
allPages = pd.DataFrame(allPages)
allPages ##this is will append on it the information
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
i= 0 # increamen 
cookies = {
    '_ga': 'GA1.2.686567735.1659437008',
    '_gid': 'GA1.2.2033456481.1659437008',
    '_gat': '1',
    'AWSALBTG': '6OywwWDzYv5+hkrGGnWiUa2j1UKE0/LMDII1ge8KjMiRu0YRY7AhDGTA8Wt59izJmdpGc6gaL9HcP1Z34yC/M4VG96w4PXNr60EErgpvL8MIKeXapzV3p15Fh/hxLgchsA17QzpCc0MIf8AF+0s12S2yiS8JPa/uYqoj0zNoG9DmNxItqxk=',
    'AWSALBTGCORS': '6OywwWDzYv5+hkrGGnWiUa2j1UKE0/LMDII1ge8KjMiRu0YRY7AhDGTA8Wt59izJmdpGc6gaL9HcP1Z34yC/M4VG96w4PXNr60EErgpvL8MIKeXapzV3p15Fh/hxLgchsA17QzpCc0MIf8AF+0s12S2yiS8JPa/uYqoj0zNoG9DmNxItqxk=',
}

headers = { #info about my chrome 
    'authority': 'sa.aqar.fm',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'app-version': '0.16.6',
    # Already added when you pass json=
    # 'content-type': 'application/json',
    # Requests sorts cookies= alphabetically
    # 'cookie': '_ga=GA1.2.686567735.1659437008; _gid=GA1.2.2033456481.1659437008; _gat=1; AWSALBTG=6OywwWDzYv5+hkrGGnWiUa2j1UKE0/LMDII1ge8KjMiRu0YRY7AhDGTA8Wt59izJmdpGc6gaL9HcP1Z34yC/M4VG96w4PXNr60EErgpvL8MIKeXapzV3p15Fh/hxLgchsA17QzpCc0MIf8AF+0s12S2yiS8JPa/uYqoj0zNoG9DmNxItqxk=; AWSALBTGCORS=6OywwWDzYv5+hkrGGnWiUa2j1UKE0/LMDII1ge8KjMiRu0YRY7AhDGTA8Wt59izJmdpGc6gaL9HcP1Z34yC/M4VG96w4PXNr60EErgpvL8MIKeXapzV3p15Fh/hxLgchsA17QzpCc0MIf8AF+0s12S2yiS8JPa/uYqoj0zNoG9DmNxItqxk=',
    'dpr': '0.666667',
    'origin': 'https://sa.aqar.fm',
    'referer': 'https://sa.aqar.fm/%D8%B4%D9%82%D9%82-%D9%84%D9%84%D8%A5%D9%8A%D8%AC%D8%A7%D8%B1/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/3?rent_type=3',
    'req-app': 'web',
    'req-device-token': '2376cd81-824f-426e-9739-a286e2a1a294',
    'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
    'viewport-width': '1528',
}
while true: # while running
    try:
        json_data = {
            'operationName': 'findListings',
            'variables': {
                'size': 20, # numer of post in a page
                'from': i, ## the page
                'sort': {
                    'create_time': 'desc',
                    'has_img': 'desc',
                },
                'where': {
                    'category': {
                        'eq': 1, ## catg (apartment , land)
                    },
                    'city_id': {
                        'eq': 21, ## city (jeddah , riyadh)
                    },
                    # 'direction_id': { 
                    #     'eq': 7, #{1 : riyadhSouth , 3:  east  , 4 : north,  7:middle }
                    # },
                    'rent_period': {
                        'eq': 3, # {1 , daily  , 2 : monthly , 3: yearly }
                    },
                },
            },
            'query': 'query findListings($size: Int, $from: Int, $sort: SortInput, $where: WhereInput, $polygon: [LocationInput!]) {\n  Web {\n    find(size: $size, from: $from, sort: $sort, where: $where, polygon: $polygon) {\n      ...WebResults\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment WebResults on WebResults {\n  listings {\n    user_id\n    id\n    uri\n    title\n    price\n    content\n    imgs\n    refresh\n    category\n    beds\n    livings\n    wc\n    area\n    type\n    street_width\n    age\n    last_update\n    street_direction\n    ketchen\n    ac\n    furnished\n    location {\n      lat\n      lng\n      __typename\n    }\n    path\n    user {\n      review\n      img\n      name\n      phone\n      iam_verified\n      rega_id\n      __typename\n    }\n    native {\n      logo\n      title\n      image\n      description\n      external_url\n      __typename\n    }\n    rent_period\n    city\n    district\n    width\n    length\n    advertiser_type\n    create_time\n    __typename\n  }\n  total\n  __typename\n}\n',
        }

        response = requests.post('https://sa.aqar.fm/graphql', cookies=cookies, headers=headers, json=json_data)
        page = response.json()
        page= page.get('data') #each page will return a dic insidde dic inside ... untill we reach the information we want 
        page= page.get('Web')
        page= page.get('find')
        page= page.get('listings')
        page = pd.DataFrame(page)
        if i != 0: # if it was the first iteration then this if statment will have error 
            if list(allPages.iloc[0])[1] ==list(page.iloc[0])[1]: # after ceratin iteration it will return to the first page this will ceck it 
                mesege = i  
                break
            
        allPages = allPages.append(page, ignore_index=True) #append the page then iterate 
        # sleep(2)
        i+=20 # increament of 20 post 
    except:
        break
# Out:
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# ...
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_10394/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate

# %%
allPages[allPages.duplicated(subset=['path'])] #check for dulactes should be nothing but i always get this one row them i drop it
# Out:
#       user_id       id                                                uri  \
# 3722  2321916  4614857                     حي-قرطبة-الرياض-الرياض-4614857
# 3723   143908  4515431  شارع-عبدالكريم-الصعيدي-حي-الرمال-الرياض-الرياض...
# 3724  1998763  4630667  شارع-أحمد-بن-قاسم-حي-المهدية-الرياض-الرياض-463...
# 3725  1314127  4601269     شارع-رقم-353-حي-المونسية-الرياض-الرياض-4601269
# 3728   978922  4618404        شارع-الأول-حي-الجزيرة-الرياض-الرياض-4618404
# ...       ...      ...                                                ...
# 6483  1592997  4507647  محطة-كهرباء-حي-قرطبة-شارع-وادي-ابراد-حي-قرطبة-...
# 6484  2605410  4587113       شارع-رقم-422-حي-الملقا-الرياض-الرياض-4587113
# 6486   656110  4410748                    الرياض-حي-الملقا-الرياض-4410748
# 6487  2319583  4609056  شارع-ابي-بن-معاذ-الانصاري-حي-الربيع-الرياض-الر...
# 6489  1361717  2525972        شارع-الغطغط-حي-الربيع-الرياض-الرياض-2525972
#
#                                                   title   price  \
# 3722          شقة للإيجار في حي قرطبة ، الرياض ، الرياض   36000
# 3723  شقة للإيجار في شارع عبدالكريم الصعيدي ، حي الر...   25000
# 3724  شقة للإيجار في شارع أحمد بن قاسم ، حي المهدية ...   26000
# 3725  شقة للإيجار في شارع رقم 353 ، حي المونسية ، ال...   32000
# 3728  شقة للإيجار في شارع الأول ، حي الجزيرة ، الريا...   35000
# ...                                                 ...     ...
# 6483  شقة للإيجار في محطة كهرباء حي قرطبة ، شارع واد...   50000
# 6484  شقة للإيجار في شارع رقم 422 ، حي الملقا ، الري...   75000
# 6486         شقة للإيجار في الرياض ، حي الملقا ، الرياض   90000
# 6487  شقة للإيجار في شارع ابي بن معاذ الانصاري ، حي ...   75000
# 6489  شقة للإيجار في شارع الغطغط ، حي الربيع ، الريا...  140000
#
#                                                 content  \
# 3722  شقة جديدة بحي قرطبة موقع جدا ممتاز في عمارة\nم...
# 3723  شقة ٤غرف وصاله \nدور اول\nحي الرمال التعمير \n...
# 3724  شقة فاخرة للإيجار بمدخلين في فلة سكنية بحي الم...
# 3725  شقه مدخل خاص \n٣غرف وصاله \nمطبخ دورتين مياه \...
# 3728  إيجار شقة ممتازه حي الجزيرة الدور الثالث علي ا...
# ...                                                 ...
# 6483  للايجار شقه شبه جديده\nحي قرطبه\nالدور الأول \...
# 6484  وصف العقار\n\nشقه ارضيه نظيفه جدا تتكون من ثلا...
# 6486  شقة ٣ غرف نوم في مجمع تليد، مؤثثه و مجهزة بالك...
# 6487  شقة للايجار في الماجدية ١١٦ حي الربيع \n\nالدو...
# 6489  موقع العقار جداً ممتاز ويتوفر في المجمع السكني...
#
#                                                    imgs     refresh  category  \
# 3722  [023219161_1660077838069.jpg, 023219163_166007...  1660665690         1
# 3723  [011991668_1658006619984.jpg, 011991662_165800...  1659527891         1
# 3724  [019987636_1660454232096.jpg, 019987634_166045...  1660757007         1
# 3725  [013141276_1659801941294.jpg, 013141270_165980...  1660576982         1
# 3728  [009789223_1660151924433.jpg, 009789228_166015...  1660203903         1
# ...                                                 ...         ...       ...
# 6483  [026210055_1657475505364.jpg, 026210059_165747...  1660441444         1
# 6484                      [025511338_1659464041951.jpg]  1660696204         1
# 6486  [006561107_1654945517910.jpg, 006561109_165494...  1659333738         1
# 6487  [023195832_1660051216697.jpg, 023195832_166005...  1660241449         1
# 6489  [500973999_1601382468230.jpg, 500973999_160138...  1660038085         1
#
#       beds  ...                                               user  native  \
# 3722     3  ...  {'review': 5, 'img': None, 'name': 'أبومحمد', ...    None
# 3723     4  ...  {'review': 4.26, 'img': '537555186_16382012763...    None
# 3724     3  ...  {'review': 4.76, 'img': '583188887_16596638062...    None
# 3725     3  ...  {'review': 4.15, 'img': '507015722_16425257044...    None
# 3728     3  ...  {'review': 4.35, 'img': '559792046_15841045855...    None
# ...    ...  ...                                                ...     ...
# 6483     3  ...  {'review': 4, 'img': '540428685_1659195225343....    None
# 6484     5  ...  {'review': 3.96, 'img': None, 'name': 'المميز ...    None
# 6486     3  ...  {'review': 4.2, 'img': '566499997_165494510286...    None
# 6487     2  ...  {'review': 4.33, 'img': None, 'name': 'فيصل بن...    None
# 6489     2  ...  {'review': 5, 'img': '500973999_1601283706842....    None
#
#       rent_period    city     district  width  length     advertiser_type  \
# 3722            3  الرياض     حي قرطبة   10.0    12.0               owner
# 3723            3  الرياض    حي الرمال  150.0     1.0     normal_marketer
# 3724            3  الرياض   حي المهدية    1.0   250.0  exclusive_marketer
# 3725            3  الرياض  حي المونسية    1.0   240.0     normal_marketer
# 3728            3  الرياض   حي الجزيرة    NaN     NaN               owner
# ...           ...     ...          ...    ...     ...                 ...
# 6483            3  الرياض     حي قرطبة    NaN     NaN               owner
# 6484            3  الرياض    حي الملقا   12.0    10.0     normal_marketer
# 6486            3  الرياض    حي الملقا   10.0    13.0               owner
# 6487            3  الرياض    حي الربيع    7.0    11.0  exclusive_marketer
# 6489            3  الرياض    حي الربيع    NaN     NaN  exclusive_marketer
#
#       create_time         __typename
# 3722   1660078477  ElasticWebListing
# 3723   1657750289  ElasticWebListing
# 3724   1660455721  ElasticWebListing
# 3725   1659802120  ElasticWebListing
# 3728   1660152287  ElasticWebListing
# ...           ...                ...
# 6483   1657475600  ElasticWebListing
# 6484   1659464113  ElasticWebListing
# 6486   1654945955  ElasticWebListing
# 6487   1659970993  ElasticWebListing
# 6489   1601383064  ElasticWebListing
#
# [1587 rows x 33 columns]

# %%
allPages = allPages.drop_duplicates(subset=['path'])
allPages = allPages.drop_duplicates(subset=['id'])

# %%
e = datetime.datetime.now()
date = f"{e.day}-{e.month}-{e.year}"
date # return the date so i store the name of the csv file to the date
# Out:
# '18-8-2022'

# %%
allPages.to_csv(f'../data/{date}.csv' , index = False)
