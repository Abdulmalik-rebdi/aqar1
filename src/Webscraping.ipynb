# %% [markdown]
# this is the first step i will webscrpe this daily

# %%
import requests
import pandas as pd
import time
import  datetime
from time import sleep
import csv
from sqlalchemy import true

# %%
allPages = []
allPages = pd.DataFrame(allPages)
allPages ##this is will append on it the information
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
i= 0 # increamen 
cookies = {
    '_ga': 'GA1.2.686567735.1659437008',
    '_gid': 'GA1.2.2033456481.1659437008',
    '_gat': '1',
    'AWSALBTG': '6OywwWDzYv5+hkrGGnWiUa2j1UKE0/LMDII1ge8KjMiRu0YRY7AhDGTA8Wt59izJmdpGc6gaL9HcP1Z34yC/M4VG96w4PXNr60EErgpvL8MIKeXapzV3p15Fh/hxLgchsA17QzpCc0MIf8AF+0s12S2yiS8JPa/uYqoj0zNoG9DmNxItqxk=',
    'AWSALBTGCORS': '6OywwWDzYv5+hkrGGnWiUa2j1UKE0/LMDII1ge8KjMiRu0YRY7AhDGTA8Wt59izJmdpGc6gaL9HcP1Z34yC/M4VG96w4PXNr60EErgpvL8MIKeXapzV3p15Fh/hxLgchsA17QzpCc0MIf8AF+0s12S2yiS8JPa/uYqoj0zNoG9DmNxItqxk=',
}

headers = { #info about my chrome 
    'authority': 'sa.aqar.fm',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'app-version': '0.16.6',
    # Already added when you pass json=
    # 'content-type': 'application/json',
    # Requests sorts cookies= alphabetically
    # 'cookie': '_ga=GA1.2.686567735.1659437008; _gid=GA1.2.2033456481.1659437008; _gat=1; AWSALBTG=6OywwWDzYv5+hkrGGnWiUa2j1UKE0/LMDII1ge8KjMiRu0YRY7AhDGTA8Wt59izJmdpGc6gaL9HcP1Z34yC/M4VG96w4PXNr60EErgpvL8MIKeXapzV3p15Fh/hxLgchsA17QzpCc0MIf8AF+0s12S2yiS8JPa/uYqoj0zNoG9DmNxItqxk=; AWSALBTGCORS=6OywwWDzYv5+hkrGGnWiUa2j1UKE0/LMDII1ge8KjMiRu0YRY7AhDGTA8Wt59izJmdpGc6gaL9HcP1Z34yC/M4VG96w4PXNr60EErgpvL8MIKeXapzV3p15Fh/hxLgchsA17QzpCc0MIf8AF+0s12S2yiS8JPa/uYqoj0zNoG9DmNxItqxk=',
    'dpr': '0.666667',
    'origin': 'https://sa.aqar.fm',
    'referer': 'https://sa.aqar.fm/%D8%B4%D9%82%D9%82-%D9%84%D9%84%D8%A5%D9%8A%D8%AC%D8%A7%D8%B1/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/3?rent_type=3',
    'req-app': 'web',
    'req-device-token': '2376cd81-824f-426e-9739-a286e2a1a294',
    'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
    'viewport-width': '1528',
}
while true: # while running
    try:
        json_data = {
            'operationName': 'findListings',
            'variables': {
                'size': 20, # numer of post in a page
                'from': i, ## the page
                'sort': {
                    'create_time': 'desc',
                    'has_img': 'desc',
                },
                'where': {
                    'category': {
                        'eq': 1, ## catg (apartment , land)
                    },
                    'city_id': {
                        'eq': 21, ## city (jeddah , riyadh)
                    },
                    # 'direction_id': { 
                    #     'eq': 7, #{1 : riyadhSouth , 3:  east  , 4 : north,  7:middle }
                    # },
                    'rent_period': {
                        'eq': 3, # {1 , daily  , 2 : monthly , 3: yearly }
                    },
                },
            },
            'query': 'query findListings($size: Int, $from: Int, $sort: SortInput, $where: WhereInput, $polygon: [LocationInput!]) {\n  Web {\n    find(size: $size, from: $from, sort: $sort, where: $where, polygon: $polygon) {\n      ...WebResults\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment WebResults on WebResults {\n  listings {\n    user_id\n    id\n    uri\n    title\n    price\n    content\n    imgs\n    refresh\n    category\n    beds\n    livings\n    wc\n    area\n    type\n    street_width\n    age\n    last_update\n    street_direction\n    ketchen\n    ac\n    furnished\n    location {\n      lat\n      lng\n      __typename\n    }\n    path\n    user {\n      review\n      img\n      name\n      phone\n      iam_verified\n      rega_id\n      __typename\n    }\n    native {\n      logo\n      title\n      image\n      description\n      external_url\n      __typename\n    }\n    rent_period\n    city\n    district\n    width\n    length\n    advertiser_type\n    create_time\n    __typename\n  }\n  total\n  __typename\n}\n',
        }

        response = requests.post('https://sa.aqar.fm/graphql', cookies=cookies, headers=headers, json=json_data)
        page = response.json()
        page= page.get('data') #each page will return a dic insidde dic inside ... untill we reach the information we want 
        page= page.get('Web')
        page= page.get('find')
        page= page.get('listings')
        page = pd.DataFrame(page)
        if i != 0: # if it was the first iteration then this if statment will have error 
            if list(allPages.iloc[0])[1] ==list(page.iloc[0])[1]: # after ceratin iteration it will return to the first page this will ceck it 
                mesege = i  
                break
            
        allPages = allPages.append(page, ignore_index=True) #append the page then iterate 
        # sleep(2)
        i+=20 # increament of 20 post 
    except:
        break
# Out:
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# ...
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate
# /tmp/ipykernel_16248/986101684.py:74: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   allPages = allPages.append(page, ignore_index=True) #append the page then iterate

# %%
allPages[allPages.duplicated(subset=['path'])] #check for dulactes should be nothing but i always get this one row them i drop it
# Out:
#       user_id       id                                                uri  \
# 1000  1142920  4613868  شارع-فاطمة-أم-الحسن-الطبري-حي-النرجس-الرياض-ال...
# 1360  2412431  4586589   شارع-يحيى-التيمي-حي-النرجس-الرياض-الرياض-4586589
# 5641  2123011  4436008  شارع-ابي-جعفر-المنصور-حي-غرناطة-الرياض-الرياض-...
# 5829   451319  4633783  شارع-السويدي-العام-الفرعي-حي-السويدي-الرياض-ال...
# 5832    44441  4443538  شارع-أبي-جعفر-المنصور-حي-غرناطة-الرياض-الرياض-...
# 5846  1775379  4497211    شارع-وادي-الشوكة-حي-قرطبة-الرياض-الرياض-4497211
# 5891   151157  4605984        شارع-رابح-حي-ظهرة-لبن-الرياض-الرياض-4605984
# 5907   456278  4458497         شارع-سكاكا-حي-العليا-الرياض-الرياض-4458497
# 5948   468055  4632334  شارع-الأمير-فهد-بن-محمد-بن-عبدالعزيز-حي-الملقا...
# 5956  1647747  4643229   شارع-يحيى-التيمي-حي-النرجس-الرياض-الرياض-4643229
#
#                                                   title  price  \
# 1000  شقة للإيجار في شارع فاطمة أم الحسن الطبري ، حي...  60000
# 1360  شقة للإيجار في شارع يحيى التيمي ، حي النرجس ، ...  65000
# 5641  شقة للإيجار في شارع ابي جعفر المنصور ، حي غرنا...  28000
# 5829  شقة للإيجار في شارع السويدي العام الفرعي ، حي ...  13000
# 5832  شقة للإيجار في شارع أبي جعفر المنصور ، حي غرنا...  30000
# 5846  شقة للإيجار في شارع وادي الشوكة ، حي قرطبة ، ا...  70000
# 5891  شقة للإيجار في شارع رابح ، حي ظهرة لبن ، الريا...  30000
# 5907  شقة للإيجار في شارع سكاكا ، حي العليا ، الرياض...  60000
# 5948  شقة للإيجار في شارع الأمير فهد بن محمد بن عبدا...  85000
# 5956  شقة للإيجار في شارع يحيى التيمي ، حي النرجس ، ...  70000
#
#                                                 content  \
# 1000  شقة مفروشة للإيجار \nالرياض، النرجس \n\nالشقة ...
# 1360  للايجار شقه فاخره في حي النرجس جنوب طريق الملك...
# 5641  شقه للايجار السنوي عوائل \nحي غرناطه \nشارع اب...
# 5829  شقة عزاب نظيفة ومنطقة هادية قريبه من الخدمات م...
# 5832  ٤ غرف وصاله ودورتين مياه .. \nمدخل واحد للشقه ...
# 5846  المزيد من التفاصيل ارسل كلمة (طابقين) عن طريق ...
# 5891  شقة دور اول مؤثثة مدخلين رجال ونساء \nمجلس ومق...
# 5907  ملاحظة : منعاً للاحراج الشقة للعوائل فقط\n\n‎ش...
# 5948  شقة للايجار في تليد كمباوند \n\nالمكونات:\n\n-...
# 5956  شقة مدخل خاص "دورين"\nدور أول وثاني \nراكب مكي...
#
#                                                    imgs     refresh  category  \
# 1000  [011429203_1660063810581.jpg, 011429205_166006...  1660575230         1
# 1360  [018073754_1659457658170.jpg, 018073756_165945...  1660554685         1
# 5641  [545004453_1655490042211.jpg, 545004453_165549...  1660432368         1
# 5829  [004513190_1660504073390.jpg, 004513195_166055...  1660586747         1
# 5832  [000444412_1655653679562.jpg, 000444413_165565...  1660116989         1
# 5846  [017753799_1658511553556.jpg, 017753794_165851...  1658511562         1
# 5891  [001511574_1659898120734.jpg, 001511572_165989...  1660150438         1
# 5907  [004562785_1655980992789.jpg, 004562787_165598...  1660383550         1
# 5948  [004680555_1660485207190.jpg, 004680556_166048...  1660486040         1
# 5956  [016477477_1660684800884.jpg, 016477474_166068...  1660685381         1
#
#       beds  ...                                               user  native  \
# 1000     3  ...  {'review': 4.73, 'img': '534505057_16414092104...    None
# 1360     3  ...  {'review': 4.64, 'img': None, 'name': 'مكتب من...    None
# 5641     2  ...  {'review': 4.57, 'img': None, 'name': 'عمرو ',...    None
# 5829     1  ...  {'review': 4.6, 'img': '555455022_164588956989...    None
# 5832     4  ...  {'review': 4.06, 'img': None, 'name': 'عقاري ا...    None
# 5846     2  ...  {'review': 4.8, 'img': None, 'name': 'مسكن و م...    None
# 5891     5  ...  {'review': 3.67, 'img': None, 'name': 'ابو محم...    None
# 5907     3  ...  {'review': 4.77, 'img': '540369077_16119968172...    None
# 5948     3  ...  {'review': 5, 'img': '552202120_1617965966409....    None
# 5956     3  ...  {'review': 4.78, 'img': '567773907_16314640398...    None
#
#       rent_period    city     district  width  length     advertiser_type  \
# 1000            3  الرياض    حي النرجس    1.0     1.0  exclusive_marketer
# 1360            3  الرياض    حي النرجس    5.0    36.0     normal_marketer
# 5641            3  الرياض    حي غرناطة   10.0    12.0                None
# 5829            3  الرياض   حي السويدي    8.0     6.0               agent
# 5832            3  الرياض    حي غرناطة   15.0    10.0               owner
# 5846            3  الرياض     حي قرطبة   21.0    21.0               agent
# 5891            3  الرياض  حي ظهرة لبن   36.0     5.0               owner
# 5907            3  الرياض    حي العليا   10.0    14.0               owner
# 5948            3  الرياض    حي الملقا   15.0    13.0               owner
# 5956            3  الرياض    حي النرجس    NaN     NaN  exclusive_marketer
#
#       create_time         __typename
# 1000   1660064087  ElasticWebListing
# 1360   1659457729  ElasticWebListing
# 5641   1655486789  ElasticWebListing
# 5829   1660503286  ElasticWebListing
# 5832   1655654746  ElasticWebListing
# 5846   1656962696  ElasticWebListing
# 5891   1659898505  ElasticWebListing
# 5907   1655981168  ElasticWebListing
# 5948   1660486039  ElasticWebListing
# 5956   1660685380  ElasticWebListing
#
# [10 rows x 33 columns]

# %%
allPages = allPages.drop_duplicates(subset=['path'])
allPages = allPages.drop_duplicates(subset=['id'])

# %%
e = datetime.datetime.now()
date = f"{e.day}-{e.month}-{e.year},{e.hour}:{e.minute}"
date # return the date so i store the name of the csv file to the date
# Out:
# '16-8-2022,21:30'

# %%
allPages.to_csv(f'../data/{date}.csv' , index = False)
